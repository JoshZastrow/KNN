# %% [markdown]
# # K-Nearest Neighbor Classifier

# %% [markdown]
# ### Objective:

# %% [markdown]
# The purpose of this script is to build a K-Nearest Neighbor (KNN) Classifier to do rudimentary image classification. This model does not include any gradient based optimization, and all the heavy lifting is done at testing time. This should serve as learning material for myself (and any readers) who are interesting in Machine Learning.

# %% [markdown]
# ### Getting Setup:

# %% [markdown]
# Import necessary modules:

# %%
import os
import random
import numpy as np
from data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %% [markdown]
# Matplotlib does not play nice with Jupyter Notebook, so here is some setup code to get it run properly. I believe '%' allows the script line to act like a command line call:

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0)  # default size of plot
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# Reload external python modules:

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Begin loading in the data:

# %%
# Get Data Directory
home = r'C:\Users\joshu\Documents\CS231n\assignment1'
cifar10_dir = home + r'\cs231n\datasets\cifar-10-batches-py'

print(cifar10_dir)
# Out:
# C:\Users\joshu\Documents\CS231n\assignment1\cs231n\datasets\cifar-10-batches-py

# %%
# utils function
X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

# Report data size
print('Training Data size: {} rows / {} cols\n'
      'Training Lbls size: {} rows / {} cols\n '
      'Test Data size: {} rows / {} cols\n'
      'Test Lbls size: {} rows / {} cols\n'.format(*X_train.shape,
                                                          *y_train.shape,
                                                          *X_test.shape,
                                                          *y_test.shape))
# Out:
# Training Data size: 50000 rows / 32 cols
# Training Lbls size: 32 rows / 3 cols
#  Test Data size: 50000 rows / 10000 cols
# Test Lbls size: 32 rows / 32 cols

# %% [markdown]
# ### Begin building the KNN Pipeline

# %%
# Visualize some data examples from each class
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
num_classes = len(classes)
samples_per_class = 7

for y, cls in enumerate(classes):
    
    idxs = np.flatnonzero(y_train == y)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    
    for i, idx in enumerate(idxs):
        
        plt_idx = i * num_classes + y + 1
        
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(X_train[idx].astype('uint8'))
        plt.axis('off')
        if i ==0:
            plt.title(cls)

print('Dataset picture examples:\n')
plt.show()
# Out:
# Dataset picture examples:

# %%
# Sub sample data set to quickly develop model
train_sample_size = 5000
mask = range(train_sample_size)
X_train = X_train[mask]
y_train = y_train[mask]

test_sample_size = 500
mask = range(test_sample_size)
X_test = X_test[mask]
y_test = y_test[mask]

# Reshape into rows
X_Train = np.reshape(X_train, (X_train.shape[0], -1))
X_test  = np.reshape(X_test, (X_test.shape[0], -1))
print('Train and Test Shapes:\n', X_train.shape, X_test.shape)
# Out:
# Train and Test Shapes:
#  (5000, 32, 32, 3) (500, 3072)

# %% [markdown]
# ### Classify the Test data with KNN

# %%
from cs231n.classifiers import KNearestNeighbor

# Instantiate a classifier object
classifier = KNearestNeighbor()
classifier.train(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-62-d35a9b55581e> in <module>()
# ----> 1 from cs231n.classifiers import KNearestNeighbor
#       2
#       3 # Instantiate a classifier object
#       4 classifier = KNearestNeighbor()
#       5 classifier.train(X_train, y_train)
#
# ImportError: No module named 'cs231n'
